# %%
import pandas as pd
import csv

# %%
a=pd.read_csv("C:/Users/Karthick/Downloads/Check-In.csv")
b=pd.read_csv("C:/Users/Karthick/Downloads/Check-Out.csv")

# %%
a.head(5)
# Out:
#    sno          DateTime Car Registration Number         VIN TYPE of Car  \
# 0    1  01-04-2018 08:00            TN01 ABCD 01  3036606711       Sedan
# 1    2  03-04-2018 08:07            TN01 ABCD 02  2862315213          HB
# 2    3  07-04-2018 18:24            TN01 ABCD 03  6350501016       Sedan
# 3    4  17-04-2018 11:00            TN01 ABCD 04  6871738958          HB
# 4    5  18-04-2018 15:10            TN01 ABCD 05  7851129374       Small
#
#    Mileage in KM Colour  Year of Manufacture Auto or Manual  \
# 0         100020    red                 2001         Manual
# 1          25000   blue                 2005         Manual
# 2          45000  green                 2010         Manual
# 3          18000    red                 2009         Manual
# 4           1023   blue                 2018           Auto
#
#        Type of Service  Visit Number         Vehicle Damages
# 0              Repairs             1  Scratches on all sides
# 1  Regular Maintenance            10  bump in passenger door
# 2  Regular Maintenance            10  bump in passenger door
# 3  Regular Maintenance            10  bump in passenger door
# 4         Free Service             2                     NaN

# %%
b.head(5)
# Out:
#    sno          DateTime Car Registration Number  Cost of Labour  \
# 0  1.0  03-04-2018 08:07            TN01 ABCD 01          3010.0
# 1  2.0  07-04-2018 18:24            TN01 ABCD 02          3830.0
# 2  3.0  17-04-2018 11:00            TN01 ABCD 03          1744.0
# 3  4.0  18-04-2018 15:10            TN01 ABCD 04          4216.0
# 4  5.0  19-04-2018 15:10            TN01 ABCD 05          4436.0
#
#    Cost of Parts Car Cleaned? Customer Feedback  Total cost
# 0         1624.0           No                 2      4634.0
# 1         1646.0           No                 3      5476.0
# 2         4529.0           No                 4      6273.0
# 3         2972.0          Yes                 5      7188.0
# 4         2915.0          Yes                 5      7351.0

# %%
b = b.dropna(axis=0)
b.head(7)
# Out:
#    sno          DateTime Car Registration Number  Cost of Labour  \
# 0  1.0  03-04-2018 08:07            TN01 ABCD 01          3010.0
# 1  2.0  07-04-2018 18:24            TN01 ABCD 02          3830.0
# 2  3.0  17-04-2018 11:00            TN01 ABCD 03          1744.0
# 3  4.0  18-04-2018 15:10            TN01 ABCD 04          4216.0
# 4  5.0  19-04-2018 15:10            TN01 ABCD 05          4436.0
# 5  6.0  17-04-2018 11:00            TN01 ABCD 03             0.0
#
#    Cost of Parts Car Cleaned? Customer Feedback  Total cost
# 0         1624.0           No                 2      4634.0
# 1         1646.0           No                 3      5476.0
# 2         4529.0           No                 4      6273.0
# 3         2972.0          Yes                 5      7188.0
# 4         2915.0          Yes                 5      7351.0
# 5          300.0           No                 3       300.0

# %%
merged = a.merge(b, on='sno')

# %%
merged
# Out:
#    sno        DateTime_x Car Registration Number_x         VIN TYPE of Car  \
# 0    1  01-04-2018 08:00              TN01 ABCD 01  3036606711       Sedan
# 1    2  03-04-2018 08:07              TN01 ABCD 02  2862315213          HB
# 2    3  07-04-2018 18:24              TN01 ABCD 03  6350501016       Sedan
# 3    3  27-04-2018 10:24              TN01 ABCD 03  6350501016       Sedan
# 4    4  17-04-2018 11:00              TN01 ABCD 04  6871738958          HB
# 5    5  18-04-2018 15:10              TN01 ABCD 05  7851129374       Small
#
#    Mileage in KM Colour  Year of Manufacture Auto or Manual  \
# 0         100020    red                 2001         Manual
# 1          25000   blue                 2005         Manual
# 2          45000  green                 2010         Manual
# 3          45200  green                 2010         Manual
# 4          18000    red                 2009         Manual
# 5           1023   blue                 2018           Auto
#
#        Type of Service  Visit Number         Vehicle Damages  \
# 0              Repairs             1  Scratches on all sides
# 1  Regular Maintenance            10  bump in passenger door
# 2  Regular Maintenance            10  bump in passenger door
# 3              Repairs            11  bump in passenger door
# 4  Regular Maintenance            10  bump in passenger door
# 5         Free Service             2                     NaN
#
#          DateTime_y Car Registration Number_y  Cost of Labour  Cost of Parts  \
# 0  03-04-2018 08:07              TN01 ABCD 01          3010.0         1624.0
# 1  07-04-2018 18:24              TN01 ABCD 02          3830.0         1646.0
# 2  17-04-2018 11:00              TN01 ABCD 03          1744.0         4529.0
# 3  17-04-2018 11:00              TN01 ABCD 03          1744.0         4529.0
# 4  18-04-2018 15:10              TN01 ABCD 04          4216.0         2972.0
# 5  19-04-2018 15:10              TN01 ABCD 05          4436.0         2915.0
#
#   Car Cleaned? Customer Feedback  Total cost
# 0           No                 2      4634.0
# 1           No                 3      5476.0
# 2           No                 4      6273.0
# 3           No                 4      6273.0
# 4          Yes                 5      7188.0
# 5          Yes                 5      7351.0

# %%
df=pd.DataFrame(merged)
df
# Out:
#    sno        DateTime_x Car Registration Number_x         VIN TYPE of Car  \
# 0    1  01-04-2018 08:00              TN01 ABCD 01  3036606711       Sedan
# 1    2  03-04-2018 08:07              TN01 ABCD 02  2862315213          HB
# 2    3  07-04-2018 18:24              TN01 ABCD 03  6350501016       Sedan
# 3    3  27-04-2018 10:24              TN01 ABCD 03  6350501016       Sedan
# 4    4  17-04-2018 11:00              TN01 ABCD 04  6871738958          HB
# 5    5  18-04-2018 15:10              TN01 ABCD 05  7851129374       Small
#
#    Mileage in KM Colour  Year of Manufacture Auto or Manual  \
# 0         100020    red                 2001         Manual
# 1          25000   blue                 2005         Manual
# 2          45000  green                 2010         Manual
# 3          45200  green                 2010         Manual
# 4          18000    red                 2009         Manual
# 5           1023   blue                 2018           Auto
#
#        Type of Service  Visit Number         Vehicle Damages  \
# 0              Repairs             1  Scratches on all sides
# 1  Regular Maintenance            10  bump in passenger door
# 2  Regular Maintenance            10  bump in passenger door
# 3              Repairs            11  bump in passenger door
# 4  Regular Maintenance            10  bump in passenger door
# 5         Free Service             2                     NaN
#
#          DateTime_y Car Registration Number_y  Cost of Labour  Cost of Parts  \
# 0  03-04-2018 08:07              TN01 ABCD 01          3010.0         1624.0
# 1  07-04-2018 18:24              TN01 ABCD 02          3830.0         1646.0
# 2  17-04-2018 11:00              TN01 ABCD 03          1744.0         4529.0
# 3  17-04-2018 11:00              TN01 ABCD 03          1744.0         4529.0
# 4  18-04-2018 15:10              TN01 ABCD 04          4216.0         2972.0
# 5  19-04-2018 15:10              TN01 ABCD 05          4436.0         2915.0
#
#   Car Cleaned? Customer Feedback  Total cost
# 0           No                 2      4634.0
# 1           No                 3      5476.0
# 2           No                 4      6273.0
# 3           No                 4      6273.0
# 4          Yes                 5      7188.0
# 5          Yes                 5      7351.0

# %%
from IPython.display import HTML
import numpy as np
import base64

# %%
def create_download_link(df, title = "Download CSV file", filename = "data.csv"):  
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

# %%
create_download_link(df)
# Out:
# <a download="data.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>

# %%
import sqlalchemy

# %%
engine = sqlalchemy.create_engine('mysql+pymysql://root:sgk123@localhost:3306/car')

# %%
df = pd.read_sql_table('customer_feedback',engine)
df
# Out:
# C:\Users\Karthick\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
#    sno  Feedback   services
# 0    1         1       poor
# 1    2         2       good
# 2    3         3       good
# 3    4         4   verygood
# 4    5         5  excellent

# %%
query='''select * from customer_feedback inner join servicestable11 on (customer_feedback.sno=servicestable11.sno)'''

# %%
df = pd.read_sql_query(query,engine)

# %%
df
# Out:
#    sno  Feedback   services  sno         checkin_time    car_number  \
# 0    1         1       poor    1  2018-04-01 08:00:00  TN01 ABCD 01
# 1    2         2       good    2  2018-04-03 08:07:00  TN01 ABCD 02
# 2    3         3       good    3  2018-04-07 18:24:00  TN01 ABCD 03
# 3    3         3       good    3  2018-04-27 10:24:00  TN01 ABCD 03
# 4    4         4   verygood    4  2018-04-17 11:00:00  TN01 ABCD 04
# 5    5         5  excellent    5  2018-04-18 15:10:00  TN01 ABCD 05
#
#           VIN Type_of_car  Mileage Colour    ...             servies_type  \
# 0  3036606711       Sedan   100020    red    ...                  Repairs
# 1  2862315213          HB    25000   blue    ...      Regular Maintenance
# 2  6350501016       Sedan    45000  green    ...      Regular Maintenance
# 3  6350501016       Sedan    45200  green    ...                  Repairs
# 4  6871738958          HB    18000    red    ...      Regular Maintenance
# 5  7851129374       Small     1023   blue    ...             Free Service
#
#   Visit_number          Vehicle_damage        checkout_time  \
# 0            1  Scratches on all sides  2018-04-03 08:07:00
# 1           10  bump in passenger door  2018-04-07 18:24:00
# 2           10  bump in passenger door  2018-04-17 11:00:00
# 3           11  bump in passenger door  2018-04-17 11:00:00
# 4           10  bump in passenger door  2018-04-18 15:10:00
# 5            2                          2018-04-19 15:10:00
#
#   Car_regsitraion_number Labor_cost Cost_of_parts  Car_cleaned  \
# 0           TN01 ABCD 01       3010          1624           No
# 1           TN01 ABCD 02       3830          1646           No
# 2           TN01 ABCD 03       1744          4529           No
# 3           TN01 ABCD 03       1744          4529           No
# 4           TN01 ABCD 04       4216          2972          Yes
# 5           TN01 ABCD 05       4436          2915          Yes
#
#    Customer_Feedback Total_cost
# 0                  2       4634
# 1                  3       5476
# 2                  4       6273
# 3                  4       6273
# 4                  5       7188
# 5                  5       7351
#
# [6 rows x 22 columns]

# %% [markdown]
# # What is the average cost of repairs of cars

# %%
query='''SELECT AVG(Total_cost) FROM servicestable11'''

# %%
df = pd.read_sql_query(query,engine)

# %%
df
# Out:
#    AVG(Total_cost)
# 0        6199.1667

# %% [markdown]
# # How many cars where brought in before 10 in the morning for service?

# %%
query="""SELECT count(checkin_time) from servicestable11 where DATE_FORMAT(checkin_time, '%%H')<=10 """

# %%
df=pd.read_sql_query(query,engine)
df
# Out:
#    count(checkin_time)
# 0                    3

# %% [markdown]
# # How many cars were brought in more than 1 time in our sample data (please dont look at visits column)?

# %%
query=''' select car_number, count(1) from servicestable11 group by car_number having count(*)>1'''

# %%
df=pd.read_sql_query(query,engine)
df
# Out:
#      car_number  count(1)
# 0  TN01 ABCD 03         2

# %% [markdown]
# # How many cars were brought on a Saturday?

# %%
query="""SELECT count(checkin_time) from servicestable11 where DATE_FORMAT(checkin_time, '%%W')="saturday" """

# %%
df=pd.read_sql_query(query,engine)
df
# Out:
#    count(checkin_time)
# 0                    1

# %% [markdown]
# # How many cars in each type (Sedan, HB, Small)?

# %%
query='''select count(sno), Type_of_car from servicestable11 group by Type_of_car'''

# %%
df=pd.read_sql_query(query,engine)
df
# Out:
#    count(sno) Type_of_car
# 0           3       Sedan
# 1           2          HB
# 2           1       Small

# %% [markdown]
# # What is the average duration for services of the car (difference between check-in and check out)

# %%
query=''' select avg(datediff(checkout_time, checkin_time)) from servicestable11'''

# %%
df=pd.read_sql_query(query,engine)
df
# Out:
#    avg(datediff(checkout_time, checkin_time))
# 0                                      1.3333

# %% [markdown]
# # What is the average customer rating?

# %%
query='''SELECT AVG(Customer_Feedback) FROM servicestable11'''

# %%
df=pd.read_sql_query(query,engine)
df
# Out:
#    AVG(Customer_Feedback)
# 0                  3.8333

# %% [markdown]
# # How many cars were brought for free service

# %%
query='''select count(servies_type) from servicestable11 where servies_type="Free Service"'''

# %%
df=pd.read_sql_query(query,engine)
df
# Out:
#    count(servies_type)
# 0                    1

# %% [markdown]
# # Which car had the maximum mileage(KM)

# %%
query='''select car_number, Mileage from servicestable11 having max(Mileage)'''

# %%
df=pd.read_sql_query(query,engine)
df
# Out:
#      car_number  Mileage
# 0  TN01 ABCD 01   100020

# %% [markdown]
# # Which car is the oldest car?

# %%
query='''select car_number, Manufacture_year from servicestable11 having min(Manufacture_year)'''

# %%
df=pd.read_sql_query(query,engine)
df
# Out:
#      car_number  Manufacture_year
# 0  TN01 ABCD 01              2001

# %% [markdown]
# # TABLE CREATOIN QUERY

# %% [markdown]
# CREATE TABLE `customer_feedback` (
#   `Feedback` int(11) NOT NULL,
#   `services` varchar(50) NOT NULL,
#   PRIMARY KEY (`Feedback`)
# )
